# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import optuna

# %% [markdown]
# Loading data

# %%
df = pd.read_csv('data/autos_clean.csv')

# %% [markdown]
# Splitting the dataset

# %%
X = df.drop('price', axis=1) # Predictors
y = df['price'] # Explained variable
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=2812) # Using random_state for reproducibility

# %% [markdown]
# Setting common hyperparameters

# %%
common_params = {'n_jobs':-1, 
                 'random_state':2812} # Using random_state for reproducibility

# %% [markdown]
# Training the baseline model

# %%
baseline_model = RandomForestRegressor(min_samples_split=8,
                                       n_estimators=15,
                                       **common_params)
baseline_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=8, n_estimators=15, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the baseline model

# %%
y_pred_test = baseline_model.predict(X_test)
y_pred_train = baseline_model.predict(X_train)


print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.94
# Test R^2: 0.87
# Diff: 0.07

# %% [markdown]
# Declaring optuna objective function

# %%
def objective_1(trial): 
    # Maximizing the test R2 score to find hyperparameters that reduce overfitting the most without sacrificing a lot of performance
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 25)

    model = RandomForestRegressor(n_estimators=n_estimators, 
                                  min_samples_split=min_samples_split, 
                                  **common_params)
    model.fit(X_train, y_train)
    
    y_pred_test = model.predict(X_test)
    score = r2_score(y_test, y_pred_test) 
    return score

# %% [markdown]
# Running the test

# %%
study_1 = optuna.create_study(direction='maximize')
# Out:
# [I 2025-06-04 13:55:24,748] A new study created in memory with name: no-name-6eb542fb-f2b1-4e4d-bc5f-9c140d458e40

# %%
study_1.optimize(objective_1, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-06-04 13:56:34,324] Trial 14 finished with value: 0.8740215468052825 and parameters: {'n_estimators': 28, 'min_samples_split': 9}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:56:37,419] Trial 2 finished with value: 0.8730286238276157 and parameters: {'n_estimators': 37, 'min_samples_split': 11}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:56:39,495] Trial 5 finished with value: 0.8713276329340982 and parameters: {'n_estimators': 41, 'min_samples_split': 13}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:56:55,813] Trial 13 finished with value: 0.8716547577738898 and parameters: {'n_estimators': 49, 'min_samples_split': 5}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:28,525] Trial 12 finished with value: 0.8680217016787599 and parameters: {'n_estimators': 81, 'min_samples_split': 25}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:29,172] Trial 7 finished with value: 0.8717192336220771 and parameters: {'n_estimators': 86, 'min_samples_split': 17}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:33,019] Trial 1 finished with value: 0.8707797009798156 and parameters: {'n_estimators': 89, 'min_samples_split': 20}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:37,276] Trial 0 finished with value: 0.8711467894023106 and parameters: {'n_estimators': 97, 'min_samples_split': 20}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:42,475] Trial 6 finished with value: 0.8702357991657805 and parameters: {'n_estimators': 100, 'min_samples_split': 22}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:57:50,696] Trial 9 finished with value: 0.8734527096451725 and parameters: {'n_estimators': 112, 'min_samples_split': 15}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:00,202] Trial 4 finished with value: 0.8715497478086202 and parameters: {'n_estimators': 115, 'min_samples_split': 20}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:03,116] Trial 3 finished with value: 0.8711423420794782 and parameters: {'n_estimators': 116, 'min_samples_split': 21}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:19,042] Trial 8 finished with value: 0.8731370158901814 and parameters: {'n_estimators': 132, 'min_samples_split': 16}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:32,041] Trial 15 finished with value: 0.8732053761738621 and parameters: {'n_estimators': 145, 'min_samples_split': 16}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:36,634] Trial 22 finished with value: 0.8724599363040815 and parameters: {'n_estimators': 30, 'min_samples_split': 14}. Best is trial 14 with value: 0.8740215468052825.
# [I 2025-06-04 13:58:55,539] Trial 16 finished with value: 0.8744209086222523 and parameters: {'n_estimators': 104, 'min_samples_split': 5}. Best is trial 16 with value: 0.8744209086222523.
# [I 2025-06-04 13:59:10,902] Trial 10 finished with value: 0.8749010449842084 and parameters: {'n_estimators': 178, 'min_samples_split': 7}. Best is trial 10 with value: 0.8749010449842084.
# [I 2025-06-04 13:59:18,709] Trial 11 finished with value: 0.8707282489635149 and parameters: {'n_estimators': 199, 'min_samples_split': 22}. Best is trial 10 with value: 0.8749010449842084.
# [I 2025-06-04 13:59:51,815] Trial 17 finished with value: 0.8751293869363935 and parameters: {'n_estimators': 148, 'min_samples_split': 9}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 13:59:53,486] Trial 19 finished with value: 0.8700678949170808 and parameters: {'n_estimators': 147, 'min_samples_split': 23}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:00:43,452] Trial 18 finished with value: 0.8740118243460034 and parameters: {'n_estimators': 197, 'min_samples_split': 12}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:00:53,527] Trial 21 finished with value: 0.8746250724858496 and parameters: {'n_estimators': 149, 'min_samples_split': 5}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:15,550] Trial 23 finished with value: 0.8746101453950006 and parameters: {'n_estimators': 159, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:38,900] Trial 24 finished with value: 0.8710549412941511 and parameters: {'n_estimators': 178, 'min_samples_split': 21}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:40,723] Trial 20 finished with value: 0.8750977942325358 and parameters: {'n_estimators': 198, 'min_samples_split': 7}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:45,184] Trial 25 finished with value: 0.8749688590320437 and parameters: {'n_estimators': 174, 'min_samples_split': 7}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:47,390] Trial 26 finished with value: 0.8745293778582611 and parameters: {'n_estimators': 170, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:01:49,830] Trial 27 finished with value: 0.8748132562386528 and parameters: {'n_estimators': 166, 'min_samples_split': 9}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:02:14,709] Trial 28 finished with value: 0.8746884579466926 and parameters: {'n_estimators': 179, 'min_samples_split': 9}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:02:34,269] Trial 29 finished with value: 0.874758348307105 and parameters: {'n_estimators': 184, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:03:04,621] Trial 31 finished with value: 0.8743846671467613 and parameters: {'n_estimators': 180, 'min_samples_split': 5}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:03:07,351] Trial 30 finished with value: 0.8749563412020164 and parameters: {'n_estimators': 189, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:03:18,033] Trial 33 finished with value: 0.8746607212235804 and parameters: {'n_estimators': 174, 'min_samples_split': 6}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:03:26,040] Trial 32 finished with value: 0.8746991098592721 and parameters: {'n_estimators': 189, 'min_samples_split': 5}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:03:45,285] Trial 34 finished with value: 0.8745837396825281 and parameters: {'n_estimators': 179, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:04:08,250] Trial 35 finished with value: 0.8746714401358746 and parameters: {'n_estimators': 183, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:04:50,189] Trial 36 finished with value: 0.8743994885809647 and parameters: {'n_estimators': 177, 'min_samples_split': 5}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:04:55,846] Trial 37 finished with value: 0.8745086245733145 and parameters: {'n_estimators': 171, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:03,350] Trial 38 finished with value: 0.8748955052128574 and parameters: {'n_estimators': 175, 'min_samples_split': 7}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:19,670] Trial 40 finished with value: 0.8745086245733145 and parameters: {'n_estimators': 171, 'min_samples_split': 8}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:20,687] Trial 39 finished with value: 0.8748787552572872 and parameters: {'n_estimators': 170, 'min_samples_split': 7}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:22,127] Trial 41 finished with value: 0.8742801017423375 and parameters: {'n_estimators': 175, 'min_samples_split': 10}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:31,076] Trial 42 finished with value: 0.874547601842155 and parameters: {'n_estimators': 187, 'min_samples_split': 10}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:31,765] Trial 43 finished with value: 0.8743034453915114 and parameters: {'n_estimators': 188, 'min_samples_split': 11}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:38,794] Trial 44 finished with value: 0.8742440742336488 and parameters: {'n_estimators': 187, 'min_samples_split': 11}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:41,005] Trial 49 finished with value: 0.8744100808561347 and parameters: {'n_estimators': 131, 'min_samples_split': 11}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:44,236] Trial 45 finished with value: 0.8742005685417914 and parameters: {'n_estimators': 191, 'min_samples_split': 11}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:46,714] Trial 47 finished with value: 0.8742241746058184 and parameters: {'n_estimators': 200, 'min_samples_split': 11}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:47,375] Trial 46 finished with value: 0.8750530881291597 and parameters: {'n_estimators': 191, 'min_samples_split': 7}. Best is trial 17 with value: 0.8751293869363935.
# [I 2025-06-04 14:05:47,673] Trial 48 finished with value: 0.8745623541000698 and parameters: {'n_estimators': 193, 'min_samples_split': 10}. Best is trial 17 with value: 0.8751293869363935.

# %%
print("Best hyperparameters:", study_1.best_params)
print("Best test set R2 score:", study_1.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 148, 'min_samples_split': 9}
# Best test set R2 score: 0.8751293869363935

# %% [markdown]
# Training the optimized model

# %%
best_model_1 = RandomForestRegressor(**study_1.best_params,
                                   **common_params)
best_model_1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=9, n_estimators=148, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the optimized model

# %%
y_pred_test = best_model_1.predict(X_test)
y_pred_train = best_model_1.predict(X_train)

print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.94
# Test R^2: 0.88
# Diff: 0.06

# %% [markdown]
# Although the difference between train and test scores hasn't improved dramatically, we were still able to find a better set of hypereparameters with optuna. A more drastic approach to reducing overfitting would be to minimize the difference between train and test scores.

# %%
def objective_2(trial): 
    # Minimizing the difference between train and test scores for maximum generalisation
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 25)

    model = RandomForestRegressor(n_estimators=n_estimators, 
                                  min_samples_split=min_samples_split, 
                                  **common_params)
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    score = r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test) 
    return score

# %%
study_2 = optuna.create_study(direction='minimize')
# Out:
# [I 2025-06-04 14:05:59,824] A new study created in memory with name: no-name-071e0a2c-a1cd-43b5-829d-1af7cb132053

# %%
study_2.optimize(objective_2, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-06-04 14:06:57,455] Trial 4 finished with value: 0.05000640320178662 and parameters: {'n_estimators': 12, 'min_samples_split': 17}. Best is trial 4 with value: 0.05000640320178662.
# [I 2025-06-04 14:08:06,914] Trial 14 finished with value: 0.04219940911700071 and parameters: {'n_estimators': 59, 'min_samples_split': 24}. Best is trial 14 with value: 0.04219940911700071.
# [I 2025-06-04 14:08:11,233] Trial 6 finished with value: 0.05346037245326085 and parameters: {'n_estimators': 66, 'min_samples_split': 15}. Best is trial 14 with value: 0.04219940911700071.
# [I 2025-06-04 14:08:15,818] Trial 15 finished with value: 0.06009666335647623 and parameters: {'n_estimators': 65, 'min_samples_split': 11}. Best is trial 14 with value: 0.04219940911700071.
# [I 2025-06-04 14:08:18,154] Trial 5 finished with value: 0.042173333872126184 and parameters: {'n_estimators': 87, 'min_samples_split': 24}. Best is trial 5 with value: 0.042173333872126184.
# [I 2025-06-04 14:08:21,949] Trial 10 finished with value: 0.04795293645807497 and parameters: {'n_estimators': 86, 'min_samples_split': 19}. Best is trial 5 with value: 0.042173333872126184.
# [I 2025-06-04 14:08:30,790] Trial 11 finished with value: 0.05644437989140383 and parameters: {'n_estimators': 91, 'min_samples_split': 13}. Best is trial 5 with value: 0.042173333872126184.
# [I 2025-06-04 14:08:31,648] Trial 13 finished with value: 0.04195236200045804 and parameters: {'n_estimators': 97, 'min_samples_split': 24}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:08:34,321] Trial 2 finished with value: 0.04739384841479988 and parameters: {'n_estimators': 103, 'min_samples_split': 19}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:08:36,047] Trial 8 finished with value: 0.05163540256251131 and parameters: {'n_estimators': 102, 'min_samples_split': 16}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:08:42,335] Trial 7 finished with value: 0.049937197428929436 and parameters: {'n_estimators': 121, 'min_samples_split': 17}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:08:43,652] Trial 3 finished with value: 0.044566510675527415 and parameters: {'n_estimators': 110, 'min_samples_split': 21}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:08:50,927] Trial 9 finished with value: 0.06859112212218188 and parameters: {'n_estimators': 113, 'min_samples_split': 7}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:09:10,364] Trial 0 finished with value: 0.06605058240257089 and parameters: {'n_estimators': 139, 'min_samples_split': 8}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:09:25,293] Trial 16 finished with value: 0.04460650741494565 and parameters: {'n_estimators': 117, 'min_samples_split': 21}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:09:31,209] Trial 18 finished with value: 0.04401813853955283 and parameters: {'n_estimators': 61, 'min_samples_split': 22}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:09:42,133] Trial 12 finished with value: 0.07226413631563233 and parameters: {'n_estimators': 162, 'min_samples_split': 6}. Best is trial 13 with value: 0.04195236200045804.
# [I 2025-06-04 14:09:50,540] Trial 1 finished with value: 0.04084167706648778 and parameters: {'n_estimators': 195, 'min_samples_split': 25}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:10:02,696] Trial 23 finished with value: 0.0534855433457484 and parameters: {'n_estimators': 48, 'min_samples_split': 15}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:11:01,417] Trial 24 finished with value: 0.06040378939467661 and parameters: {'n_estimators': 78, 'min_samples_split': 11}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:12:17,465] Trial 21 finished with value: 0.042727591125744424 and parameters: {'n_estimators': 152, 'min_samples_split': 23}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:12:23,565] Trial 22 finished with value: 0.07604593843759844 and parameters: {'n_estimators': 126, 'min_samples_split': 5}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:12:27,330] Trial 19 finished with value: 0.06346658291928808 and parameters: {'n_estimators': 157, 'min_samples_split': 9}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:12:51,611] Trial 17 finished with value: 0.059614675290678654 and parameters: {'n_estimators': 188, 'min_samples_split': 11}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:13:08,043] Trial 20 finished with value: 0.04970925183530317 and parameters: {'n_estimators': 182, 'min_samples_split': 17}. Best is trial 1 with value: 0.04084167706648778.
# [I 2025-06-04 14:13:13,815] Trial 26 finished with value: 0.04073633427647483 and parameters: {'n_estimators': 165, 'min_samples_split': 25}. Best is trial 26 with value: 0.04073633427647483.
# [I 2025-06-04 14:13:23,444] Trial 25 finished with value: 0.06635693856829383 and parameters: {'n_estimators': 170, 'min_samples_split': 8}. Best is trial 26 with value: 0.04073633427647483.
# [I 2025-06-04 14:13:37,777] Trial 28 finished with value: 0.04092555634512385 and parameters: {'n_estimators': 179, 'min_samples_split': 25}. Best is trial 26 with value: 0.04073633427647483.
# [I 2025-06-04 14:13:43,663] Trial 27 finished with value: 0.07226926842674541 and parameters: {'n_estimators': 170, 'min_samples_split': 6}. Best is trial 26 with value: 0.04073633427647483.
# [I 2025-06-04 14:13:47,817] Trial 29 finished with value: 0.04092555634512385 and parameters: {'n_estimators': 179, 'min_samples_split': 25}. Best is trial 26 with value: 0.04073633427647483.
# [I 2025-06-04 14:13:51,575] Trial 37 finished with value: 0.040732191674986984 and parameters: {'n_estimators': 33, 'min_samples_split': 25}. Best is trial 37 with value: 0.040732191674986984.
# [I 2025-06-04 14:14:02,916] Trial 30 finished with value: 0.040916572755235636 and parameters: {'n_estimators': 178, 'min_samples_split': 25}. Best is trial 37 with value: 0.040732191674986984.
# [I 2025-06-04 14:14:12,893] Trial 31 finished with value: 0.04085617914896045 and parameters: {'n_estimators': 190, 'min_samples_split': 25}. Best is trial 37 with value: 0.040732191674986984.
# [I 2025-06-04 14:14:18,378] Trial 40 finished with value: 0.04073219167498687 and parameters: {'n_estimators': 33, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:14:36,889] Trial 32 finished with value: 0.04084167706648767 and parameters: {'n_estimators': 195, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:14:37,829] Trial 33 finished with value: 0.0408298294038415 and parameters: {'n_estimators': 191, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:14:46,031] Trial 34 finished with value: 0.04079915781173726 and parameters: {'n_estimators': 189, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:15:34,084] Trial 35 finished with value: 0.04084849722986028 and parameters: {'n_estimators': 200, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:15:38,036] Trial 49 finished with value: 0.04701786236003902 and parameters: {'n_estimators': 23, 'min_samples_split': 20}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:15:59,961] Trial 36 finished with value: 0.04084173672123692 and parameters: {'n_estimators': 197, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:07,444] Trial 38 finished with value: 0.04084173672123692 and parameters: {'n_estimators': 197, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:16,963] Trial 39 finished with value: 0.04084849722986028 and parameters: {'n_estimators': 200, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:22,189] Trial 41 finished with value: 0.04086578365267479 and parameters: {'n_estimators': 175, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:24,999] Trial 47 finished with value: 0.04334786621063491 and parameters: {'n_estimators': 135, 'min_samples_split': 22}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:26,104] Trial 42 finished with value: 0.040824638356428467 and parameters: {'n_estimators': 199, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:30,032] Trial 43 finished with value: 0.04084167706648767 and parameters: {'n_estimators': 195, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:30,515] Trial 44 finished with value: 0.0408859582154697 and parameters: {'n_estimators': 194, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:31,295] Trial 45 finished with value: 0.040842769910948595 and parameters: {'n_estimators': 196, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:31,939] Trial 46 finished with value: 0.04084849722986028 and parameters: {'n_estimators': 200, 'min_samples_split': 25}. Best is trial 40 with value: 0.04073219167498687.
# [I 2025-06-04 14:16:33,131] Trial 48 finished with value: 0.046085818412020196 and parameters: {'n_estimators': 198, 'min_samples_split': 20}. Best is trial 40 with value: 0.04073219167498687.

# %%
print("Best hyperparameters:", study_2.best_params)
print("Best test set R2 score:", study_2.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 33, 'min_samples_split': 25}
# Best test set R2 score: 0.04073219167498687

# %% [markdown]
# Training the optimized model

# %%
best_model_2 = RandomForestRegressor(**study_2.best_params,
                                   **common_params)
best_model_2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=25, n_estimators=33, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the optimized model

# %%
y_pred_test = best_model_2.predict(X_test)
y_pred_train = best_model_2.predict(X_train)

print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.91
# Test R^2: 0.87
# Diff: 0.04

# %% [markdown]
# Now the model generalizes almost twice as good as the baseline model. Ideally, we should optimise other parameters as well, such as max_depth
