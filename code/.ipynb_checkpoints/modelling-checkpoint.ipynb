# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import optuna

# %% [markdown]
# Loading data

# %%
df = pd.read_csv('../data/autos_clean.csv')

# %% [markdown]
# Splitting the dataset

# %%
X = df.drop('price', axis=1) # Predictors
y = df['price'] # Explained variable
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=2812) # Using random_state for reproducibility

# %% [markdown]
# Setting common hyperparameters

# %%
common_params = {'n_jobs':-1, 
                 'random_state':2812} # Using random_state for reproducibility

# %% [markdown]
# Training the baseline model

# %%
baseline_model = RandomForestRegressor(min_samples_split=8,
                                       n_estimators=15,
                                       **common_params)
baseline_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=8, n_estimators=15, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the baseline model

# %%
y_pred_test = baseline_model.predict(X_test)
y_pred_train = baseline_model.predict(X_train)


print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.94
# Test R^2: 0.87
# Diff: 0.07

# %% [markdown]
# Declaring optuna objective function

# %%
def objective_1(trial): 
    # Maximizing the test R2 score to find hyperparameters that reduce overfitting the most without sacrificing a lot of performance
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 25)

    model = RandomForestRegressor(n_estimators=n_estimators, 
                                  min_samples_split=min_samples_split, 
                                  **common_params)
    model.fit(X_train, y_train)
    
    y_pred_test = model.predict(X_test)
    score = r2_score(y_test, y_pred_test) 
    return score

# %% [markdown]
# Running the test

# %%
study_1 = optuna.create_study(direction='maximize')
# Out:
# [I 2025-06-06 17:39:57,644] A new study created in memory with name: no-name-7498ab77-f6ce-47d2-b884-e69d076a0f59

# %%
study_1.optimize(objective_1, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-06-06 17:40:38,827] Trial 4 finished with value: 0.8684323158055867 and parameters: {'n_estimators': 11, 'min_samples_split': 17}. Best is trial 4 with value: 0.8684323158055867.
# [I 2025-06-06 17:41:29,145] Trial 10 finished with value: 0.8718761279935423 and parameters: {'n_estimators': 40, 'min_samples_split': 14}. Best is trial 10 with value: 0.8718761279935423.
# [I 2025-06-06 17:41:37,404] Trial 0 finished with value: 0.8714609299353582 and parameters: {'n_estimators': 43, 'min_samples_split': 14}. Best is trial 10 with value: 0.8718761279935423.
# [I 2025-06-06 17:41:39,453] Trial 14 finished with value: 0.8698781835284332 and parameters: {'n_estimators': 44, 'min_samples_split': 18}. Best is trial 10 with value: 0.8718761279935423.
# [I 2025-06-06 17:41:39,505] Trial 13 finished with value: 0.871069110213035 and parameters: {'n_estimators': 44, 'min_samples_split': 15}. Best is trial 10 with value: 0.8718761279935423.
# [I 2025-06-06 17:41:39,530] Trial 3 finished with value: 0.8725470574410219 and parameters: {'n_estimators': 46, 'min_samples_split': 8}. Best is trial 3 with value: 0.8725470574410219.
# [I 2025-06-06 17:42:01,792] Trial 7 finished with value: 0.8707406361543512 and parameters: {'n_estimators': 69, 'min_samples_split': 18}. Best is trial 3 with value: 0.8725470574410219.
# [I 2025-06-06 17:42:16,042] Trial 6 finished with value: 0.8733754899337198 and parameters: {'n_estimators': 72, 'min_samples_split': 6}. Best is trial 6 with value: 0.8733754899337198.
# [I 2025-06-06 17:42:34,356] Trial 17 finished with value: 0.8683095300864979 and parameters: {'n_estimators': 26, 'min_samples_split': 23}. Best is trial 6 with value: 0.8733754899337198.
# [I 2025-06-06 17:42:38,708] Trial 5 finished with value: 0.8733632667951773 and parameters: {'n_estimators': 88, 'min_samples_split': 5}. Best is trial 6 with value: 0.8733754899337198.
# [I 2025-06-06 17:42:47,412] Trial 8 finished with value: 0.8726298590383681 and parameters: {'n_estimators': 109, 'min_samples_split': 16}. Best is trial 6 with value: 0.8733754899337198.
# [I 2025-06-06 17
 'min_samples_split': 9}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:49:11,613] Trial 38 finished with value: 0.8745514042043221 and parameters: {'n_estimators': 200, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:49:18,769] Trial 39 finished with value: 0.8749939245037782 and parameters: {'n_estimators': 198, 'min_samples_split': 9}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:49:28,772] Trial 41 finished with value: 0.8743680731108853 and parameters: {'n_estimators': 158, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:05,337] Trial 49 finished with value: 0.8746380604646582 and parameters: {'n_estimators': 146, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:14,574] Trial 42 finished with value: 0.8745514042043221 and parameters: {'n_estimators': 200, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:18,451] Trial 43 finished with value: 0.8745965111567734 and parameters: {'n_estimators': 199, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:18,556] Trial 44 finished with value: 0.8745965111567733 and parameters: {'n_estimators': 199, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:19,821] Trial 47 finished with value: 0.8745418531361243 and parameters: {'n_estimators': 194, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:19,929] Trial 45 finished with value: 0.8750991223334025 and parameters: {'n_estimators': 200, 'min_samples_split': 7}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:20,727] Trial 48 finished with value: 0.874591492043539 and parameters: {'n_estimators': 197, 'min_samples_split': 10}. Best is trial 25 with value: 0.8751293869363935.
# [I 2025-06-06 17:50:20,925] Trial 46 finished with value: 0.875140264589207 and parameters: {'n_estimators': 199, 'min_samples_split': 7}. Best is trial 46 with value: 0.875140264589207.

# %%
print("Best hyperparameters:", study_1.best_params)
print("Best test set R2 score:", study_1.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 199, 'min_samples_split': 7}
# Best test set R2 score: 0.875140264589207

# %% [markdown]
# Training the optimized model

# %%
best_model_1 = RandomForestRegressor(**study_1.best_params,
                                   **common_params)
best_model_1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=7, n_estimators=199, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the optimized model

# %%
y_pred_test = best_model_1.predict(X_test)
y_pred_train = best_model_1.predict(X_train)

print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.94
# Test R^2: 0.88
# Diff: 0.07

# %% [markdown]
# Although the difference between train and test scores hasn't improved dramatically, we were still able to find a better set of hypereparameters with optuna. A more drastic approach to reducing overfitting would be to minimize the difference between train and test scores.

# %%
def objective_2(trial): 
    # Minimizing the difference between train and test scores for maximum generalisation
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 25)

    model = RandomForestRegressor(n_estimators=n_estimators, 
                                  min_samples_split=min_samples_split, 
                                  **common_params)
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    score = r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test) 
    return score

# %%
study_2 = optuna.create_study(direction='minimize')
# Out:
# [I 2025-06-06 17:50:37,247] A new study created in memory with name: no-name-91de0d41-b114-4746-a514-5e2c7151932e

# %%
study_2.optimize(objective_2, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-06-06 17:51:09,167] Trial 0 finished with value: 0.057452232402123715 and parameters: {'n_estimators': 15, 'min_samples_split': 13}. Best is trial 0 with value: 0.057452232402123715.
# [I 2025-06-06 17:51:09,603] Trial 11 finished with value: 0.059878896318221964 and parameters: {'n_estimators': 14, 'min_samples_split': 11}. Best is trial 0 with value: 0.057452232402123715.
# [I 2025-06-06 17:51:34,531] Trial 1 finished with value: 0.052513559044514935 and parameters: {'n_estimators': 25, 'min_samples_split': 16}. Best is trial 1 with value: 0.052513559044514935.
# [I 2025-06-06 17:51:35,304] Trial 15 finished with value: 0.049264207490668954 and parameters: {'n_estimators': 20, 'min_samples_split': 18}. Best is trial 15 with value: 0.049264207490668954.
# [I 2025-06-06 17:52:14,034] Trial 5 finished with value: 0.045317153802411414 and parameters: {'n_estimators': 59, 'min_samples_split': 21}. Best is trial 5 with value: 0.045317153802411414.
 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:18,643] Trial 29 finished with value: 0.040824638356428467 and parameters: {'n_estimators': 199, 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:26,675] Trial 31 finished with value: 0.04092555634512385 and parameters: {'n_estimators': 179, 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:27,305] Trial 30 finished with value: 0.04084167706648778 and parameters: {'n_estimators': 195, 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:34,713] Trial 36 finished with value: 0.04075547798762402 and parameters: {'n_estimators': 147, 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:50,376] Trial 32 finished with value: 0.04078376700129549 and parameters: {'n_estimators': 192, 'min_samples_split': 25}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:51,191] Trial 33 finished with value: 0.04181959532631452 and parameters: {'n_estimators': 183, 'min_samples_split': 24}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:58,355] Trial 34 finished with value: 0.04178810362727903 and parameters: {'n_estimators': 182, 'min_samples_split': 24}. Best is trial 7 with value: 0.040742747316842465.
# [I 2025-06-06 17:58:59,664] Trial 37 finished with value: 0.04072778173589564 and parameters: {'n_estimators': 161, 'min_samples_split': 25}. Best is trial 37 with value: 0.04072778173589564.
# [I 2025-06-06 17:59:01,020] Trial 35 finished with value: 0.040916572755235636 and parameters: {'n_estimators': 178, 'min_samples_split': 25}. Best is trial 37 with value: 0.04072778173589564.
# [I 2025-06-06 17:59:07,913] Trial 38 finished with value: 0.04081243703060944 and parameters: {'n_estimators': 164, 'min_samples_split': 25}. Best is trial 37 with value: 0.04072778173589564.
# [I 2025-06-06 17:59:42,900] Trial 39 finished with value: 0.040764135326042505 and parameters: {'n_estimators': 158, 'min_samples_split': 25}. Best is trial 37 with value: 0.04072778173589564.
# [I 2025-06-06 18:00:12,333] Trial 40 finished with value: 0.04070115417628706 and parameters: {'n_estimators': 160, 'min_samples_split': 25}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:14,988] Trial 41 finished with value: 0.04076790114661777 and parameters: {'n_estimators': 166, 'min_samples_split': 25}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:17,343] Trial 42 finished with value: 0.04072778173589564 and parameters: {'n_estimators': 161, 'min_samples_split': 25}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:23,011] Trial 43 finished with value: 0.04075134105479539 and parameters: {'n_estimators': 159, 'min_samples_split': 25}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:29,674] Trial 46 finished with value: 0.04453182671273659 and parameters: {'n_estimators': 158, 'min_samples_split': 21}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:30,112] Trial 45 finished with value: 0.04451038781963679 and parameters: {'n_estimators': 159, 'min_samples_split': 21}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:30,534] Trial 48 finished with value: 0.04451038781963679 and parameters: {'n_estimators': 159, 'min_samples_split': 21}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:30,629] Trial 44 finished with value: 0.040842769910948484 and parameters: {'n_estimators': 196, 'min_samples_split': 25}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:30,699] Trial 47 finished with value: 0.04452529890337187 and parameters: {'n_estimators': 162, 'min_samples_split': 21}. Best is trial 40 with value: 0.04070115417628706.
# [I 2025-06-06 18:00:31,292] Trial 49 finished with value: 0.04457426044913826 and parameters: {'n_estimators': 155, 'min_samples_split': 21}. Best is trial 40 with value: 0.04070115417628706.

# %%
print("Best hyperparameters:", study_2.best_params)
print("Best test set R2 score:", study_2.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 160, 'min_samples_split': 25}
# Best test set R2 score: 0.04070115417628706

# %% [markdown]
# Training the optimized model

# %%
best_model_2 = RandomForestRegressor(**study_2.best_params,
                                   **common_params)
best_model_2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=25, n_estimators=160, n_jobs=-1,
#                       random_state=2812)

# %% [markdown]
# Testing the optimized model

# %%
y_pred_test = best_model_2.predict(X_test)
y_pred_train = best_model_2.predict(X_train)

print(f"Train R^2: {np.round(r2_score(y_train, y_pred_train),2)}")
print(f"Test R^2: {np.round(r2_score(y_test, y_pred_test),2)}")
print(f"Diff: {np.round(r2_score(y_train, y_pred_train) - r2_score(y_test, y_pred_test),2)}")
# Out:
# Train R^2: 0.91
# Test R^2: 0.87
# Diff: 0.04

# %% [markdown]
# Now the model generalizes almost twice as good as the baseline model. Ideally, we should optimise other parameters as well, such as max_depth
